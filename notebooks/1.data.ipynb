# %%
import uuid
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
print("kernel working")
# Out:
# kernel working

# %% [markdown]
# # 1. Generate Categories

# %% [markdown]
# ## Category Table
#
# Matches the `Category` table in the production Prisma schema. No foreign key
# dependencies — generated first.
#
# | Column     | Type            | Notes                                      |
# |------------|-----------------|---------------------------------------------|
# | `id`       | String (PK)     | UUID, generated via `uuid.uuid4()`          |
# | `name`     | String          | Category display name                       |
# | `slug`     | String          | Unique, URL-friendly (lowercase, hyphenated)|
# | `parentId` | String? (FK)    | Nullable — supports nested categories, set to `None` for this initial batch (flat categories only, no sub-categories yet) |
#
# **Generated rows:** 8 top-level categories — Electronics, Clothing, Home and
# Garden, Beauty and Personal Care, Sports and Outdoors, Books, Toys and Games,
# Groceries.
#
# **Output:** saved to `data/output/categories.csv`m

# %%
category_names = [
    "Electronics", "Clothing", "Home and Garden",
    "Beauty and Personal Care", "Sports and Outdoors",
    "Books", "Toys and Games", "Groceries"
]

categories = []
for name in category_names:
    category = {
        "id": str(uuid.uuid4()),        # ← this is what you just tested
        "name": name,
        "slug": name.lower().replace(" ", "-"),
        "parentId": None
    }
    categories.append(category)

categories
# Out:
# [{'id': 'f1734bdc-1bd8-41d7-a347-608eff237041',
#   'name': 'Electronics',
#   'slug': 'electronics',
#   'parentId': None},
#  {'id': '0c4c8110-d542-431d-87fd-89c15fb61e5b',
#   'name': 'Clothing',
#   'slug': 'clothing',
#   'parentId': None},
#  {'id': '4f2cb014-abf4-42d6-93f8-f801ea7b1173',
#   'name': 'Home and Garden',
#   'slug': 'home-and-garden',
#   'parentId': None},
#  {'id': '1c05029c-c897-4135-a7d0-cb3f9130bb3f',
#   'name': 'Beauty and Personal Care',
#   'slug': 'beauty-and-personal-care',
#   'parentId': None},
#  {'id': '7adad1e0-c8e3-4c6d-8d7d-81873cecb006',
#   'name': 'Sports and Outdoors',
#   'slug': 'sports-and-outdoors',
#   'parentId': None},
#  {'id': '167dd0df-3dc4-4f24-84ce-c8fd765905a4',
#   'name': 'Books',
#   'slug': 'books',
#   'parentId': None},
#  {'id': '04a586fb-05d6-43e7-8899-82be5e81b1f7',
#   'name': 'Toys and Games',
#   'slug': 'toys-and-games',
#   'parentId': None},
#  {'id': 'a9f62412-ab4e-46a4-b908-215d900d4611',
#   'name': 'Groceries',
#   'slug': 'groceries',
#   'parentId': None}]

# %%
categories_df = pd.DataFrame(categories)
categories_df
# Out:
#                                      id                      name  \
# 0  f1734bdc-1bd8-41d7-a347-608eff237041               Electronics
# 1  0c4c8110-d542-431d-87fd-89c15fb61e5b                  Clothing
# 2  4f2cb014-abf4-42d6-93f8-f801ea7b1173           Home and Garden
# 3  1c05029c-c897-4135-a7d0-cb3f9130bb3f  Beauty and Personal Care
# 4  7adad1e0-c8e3-4c6d-8d7d-81873cecb006       Sports and Outdoors
# 5  167dd0df-3dc4-4f24-84ce-c8fd765905a4                     Books
# 6  04a586fb-05d6-43e7-8899-82be5e81b1f7            Toys and Games
# 7  a9f62412-ab4e-46a4-b908-215d900d4611                 Groceries
#
#                        slug parentId
# 0               electronics     None
# 1                  clothing     None
# 2           home-and-garden     None
# 3  beauty-and-personal-care     None
# 4       sports-and-outdoors     None
# 5                     books     None
# 6            toys-and-games     None
# 7                 groceries     None

# %%
categories_df.to_csv("../data/output/categories.csv", index=False)

# %% [markdown]
# # 2. Generate Brands

# %% [markdown]
# Matches the `Brand` table in the production Prisma schema. No foreign key
# dependencies — generated independently of Category (they only connect later,
# through `Product`, which references both `categoryId` and `brandId`).
#
# | Column    | Type         | Notes                                  |
# |-----------|--------------|------------------------------------------|
# | `id`      | String (PK) | UUID, generated via `uuid.uuid4()`      |
# | `name`    | String       | Brand display name                       |
# | `slug`    | String       | Unique, URL-friendly (lowercase, hyphenated) |
# | `logoUrl` | String?      | Nullable — set to `None` for now, no real logos yet |
#
# **Output:** saved to `data/output/brands.csv`

# %%
brand_names = [
    "Nova", "Zenith", "Urban Edge", "Pure Living", "Apex Gear",
    "Bright Home", "Trendify", "Everyday Essentials", "Peak Performance",
    "Lumin", "Craft & Co", "Vitality", "Solstice", "Momentum"
]

# %%
brands = []
for name in brand_names:
    brand = {
        "id":str(uuid.uuid4()),
        "name":name,
        "slug": name.lower().replace(" ", "-").replace("&", "").replace("--", "-"),
        "logoUrl": None}
    brands.append(brand)

# %%
brands
# Out:
# [{'id': 'b19fe2de-64e1-4aef-bf35-89c68e1bc005',
#   'name': 'Nova',
#   'slug': 'nova',
#   'logoUrl': None},
#  {'id': '7ed30906-9158-4080-9620-7444f1efbb89',
#   'name': 'Zenith',
#   'slug': 'zenith',
#   'logoUrl': None},
#  {'id': 'f1982394-18c3-461a-a6cd-a3725cac523d',
#   'name': 'Urban Edge',
#   'slug': 'urban-edge',
#   'logoUrl': None},
#  {'id': 'e815bf70-d643-4b09-9349-148e5851e81d',
#   'name': 'Pure Living',
#   'slug': 'pure-living',
#   'logoUrl': None},
#  {'id': 'd6355ed7-afff-4159-894a-6a5b47729077',
#   'name': 'Apex Gear',
#   'slug': 'apex-gear',
#   'logoUrl': None},
#  {'id': 'd5581f60-0fd6-4e44-9bbc-70cf21247ccc',
#   'name': 'Bright Home',
#   'slug': 'bright-home',
#   'logoUrl': None},
#  {'id': '49b5df83-6d61-48dd-8b3b-6190e3914ab7',
#   'name': 'Trendify',
#   'slug': 'trendify',
#   'logoUrl': None},
#  {'id': '6b170806-0d69-4202-b93b-a16a2387427e',
#   'name': 'Everyday Essentials',
#   'slug': 'everyday-essentials',
#   'logoUrl': None},
#  {'id': '9b8511d2-b543-41c7-a58e-f20047f2c242',
#   'name': 'Peak Performance',
#   'slug': 'peak-performance',
#   'logoUrl': None},
#  {'id': '0627c61d-cd13-4018-aaca-a9074c34b06b',
#   'name': 'Lumin',
#   'slug': 'lumin',
#   'logoUrl': None},
#  {'id': '40ccb017-95e0-4aec-aab9-16cc8ebead44',
#   'name': 'Craft & Co',
#   'slug': 'craft-&-co',
#   'logoUrl': None},
#  {'id': 'abbafd71-53f1-4d5c-b138-e02aa2bff161',
#   'name': 'Vitality',
#   'slug': 'vitality',
#   'logoUrl': None},
#  {'id': '336934a3-6440-42ff-92ad-162da0f78d7c',
#   'name': 'Solstice',
#   'slug': 'solstice',
#   'logoUrl': None},
#  {'id': '24cbfb69-b7eb-4e67-b87b-430a101c78c2',
#   'name': 'Momentum',
#   'slug': 'momentum',
#   'logoUrl': None}]

# %%
brands_df = pd.DataFrame(brands)
brands_df
# Out:
#                                       id                 name  \
# 0   1cdf4477-f1db-4444-ac52-cb34c06bdf98                 Nova
# 1   02664f5d-9fc8-4a73-ad4d-af0c636ac975               Zenith
# 2   d9473997-4972-49fa-afca-292f068b1c0d           Urban Edge
# 3   0709ae63-126c-48f5-bfd7-249e276cc1d0          Pure Living
# 4   6a33a8e0-b007-4bab-a5d8-fe7334e1571e            Apex Gear
# 5   bc8e5b81-224b-49b8-a9e0-617276d0601a          Bright Home
# 6   38fe5ff3-331d-49a1-afde-2111ae92f3a3             Trendify
# 7   2578be8c-af9e-4366-8e87-f6b6132a0d4d  Everyday Essentials
# 8   28660588-c024-4d81-8d09-8bd42223f1a9     Peak Performance
# 9   584f0bfe-f600-4cbc-9ff3-923419ba96ed                Lumin
# 10  278f3623-d35c-48bb-a43e-94635e8cef64           Craft & Co
# 11  f87917e9-127f-403b-9e44-65092d81f281             Vitality
# 12  89ea2f17-c2ca-4fef-ae5a-6dd6957c69a1             Solstice
# 13  5ac558dd-7bb9-4a4b-bb5b-98235542daca             Momentum
#
#                    slug logoUrl
# 0                  nova    None
# 1                zenith    None
# 2            urban-edge    None
# 3           pure-living    None
# 4             apex-gear    None
# 5           bright-home    None
# 6              trendify    None
# 7   everyday-essentials    None
# 8      peak-performance    None
# 9                 lumin    None
# 10             craft-co    None
# 11             vitality    None
# 12             solstice    None
# 13             momentum    None

# %%
brands_df.to_csv("../data/output/brands.csv", index=False)

# %% [markdown]
# # 3. Generate Products

# %%
num_products = 150
products = [] 
for i in range(num_products):
    category = categories[np.random.randint(0,len(categories))]
    brand = brands[np.random.randint(0,len(brands))]

    product = {
        "id": str(uuid.uuid4()),
        "name":f"{category['name']} Product {i}",
        "slug": f"{category['name']} Product {i}".lower().replace(" ", "-"),
        "description": f"A great {category['name']} product from {brand['name']}.",
        "categoryId":category["id"],
        "brandId":brand["id"],
        "basePrice": np.random.uniform(1000, 10000),
        "createdAt": "2026-01-01",
        "updatedAt": "2026-01-01"}
    products.append(product)

# %%
products_df = pd.DataFrame(products)

# %%
products_df
# Out:
#                                        id  \
# 0    bb483a44-bc2e-4d87-822d-04071d6bc9d2
# 1    730f446e-d92f-42fc-9bda-c2faa1039493
# 2    ba3ede2d-bc2d-4295-819a-acf758e2ffcd
# 3    3a18c9ee-7789-444e-a861-7a357c645238
# 4    d44025be-1f64-46e7-b713-4921303ea488
# ..                                    ...
# 145  aecf5e98-01f3-4fbf-81cf-fbccbf9081f5
# 146  f62ac818-36d6-4f1a-a9dd-846b5046ff40
# 147  bbf6b6f2-9d08-4d58-a6db-3abed090f1cb
# 148  5886affb-c157-4d67-9b8e-71273d373301
# 149  92b97174-851a-4223-8ff2-48252d4c22c3
#
#                                      name  \
# 0               Home and Garden Product 0
# 1           Sports and Outdoors Product 1
# 2                     Groceries Product 2
# 3                         Books Product 3
# 4                      Clothing Product 4
# ..                                    ...
# 145            Toys and Games Product 145
# 146  Beauty and Personal Care Product 146
# 147                 Groceries Product 147
# 148                 Groceries Product 148
# 149  Beauty and Personal Care Product 149
#
#                                      slug  \
# 0               home-and-garden-product-0
# 1           sports-and-outdoors-product-1
# 2                     groceries-product-2
# 3                         books-product-3
# 4                      clothing-product-4
# ..                                    ...
# 145            toys-and-games-product-145
# 146  beauty-and-personal-care-product-146
# 147                 groceries-product-147
# 148                 groceries-product-148
# 149  beauty-and-personal-care-product-149
#
#                                            description  \
# 0     A great Home and Garden product from Craft & Co.
# 1    A great Sports and Outdoors product from Peak ...
# 2     A great Groceries product from Peak Performance.
# 3                 A great Books product from Solstice.
# 4    A great Clothing product from Everyday Essenti...
# ..                                                 ...
# 145  A great Toys and Games product from Everyday E...
# 146  A great Beauty and Personal Care product from ...
# 147         A great Groceries product from Craft & Co.
# 148        A great Groceries product from Pure Living.
# 149  A great Beauty and Personal Care product from ...
#
#                                categoryId  \
# 0    4f2cb014-abf4-42d6-93f8-f801ea7b1173
# 1    7adad1e0-c8e3-4c6d-8d7d-81873cecb006
# 2    a9f62412-ab4e-46a4-b908-215d900d4611
# 3    167dd0df-3dc4-4f24-84ce-c8fd765905a4
# 4    0c4c8110-d542-431d-87fd-89c15fb61e5b
# ..                                    ...
# 145  04a586fb-05d6-43e7-8899-82be5e81b1f7
# 146  1c05029c-c897-4135-a7d0-cb3f9130bb3f
# 147  a9f62412-ab4e-46a4-b908-215d900d4611
# 148  a9f62412-ab4e-46a4-b908-215d900d4611
# 149  1c05029c-c897-4135-a7d0-cb3f9130bb3f
#
#                                   brandId    basePrice   createdAt   updatedAt
# 0    278f3623-d35c-48bb-a43e-94635e8cef64  9791.501560  2026-01-01  2026-01-01
# 1    28660588-c024-4d81-8d09-8bd42223f1a9  9342.636274  2026-01-01  2026-01-01
# 2    28660588-c024-4d81-8d09-8bd42223f1a9  2871.012234  2026-01-01  2026-01-01
# 3    89ea2f17-c2ca-4fef-ae5a-6dd6957c69a1  4828.749656  2026-01-01  2026-01-01
# 4    2578be8c-af9e-4366-8e87-f6b6132a0d4d  6800.590048  2026-01-01  2026-01-01
# ..                                    ...          ...         ...         ...
# 145  2578be8c-af9e-4366-8e87-f6b6132a0d4d  5736.785600  2026-01-01  2026-01-01
# 146  584f0bfe-f600-4cbc-9ff3-923419ba96ed  8639.553950  2026-01-01  2026-01-01
# 147  278f3623-d35c-48bb-a43e-94635e8cef64  6206.762017  2026-01-01  2026-01-01
# 148  0709ae63-126c-48f5-bfd7-249e276cc1d0  3398.117290  2026-01-01  2026-01-01
# 149  d9473997-4972-49fa-afca-292f068b1c0d  8646.715808  2026-01-01  2026-01-01
#
# [150 rows x 9 columns]

# %%
products_df.to_csv("../data/output/products.csv", index=False)

# %% [markdown]
# # 4. product varient

# %%
category_lookup = {}
for cat in categories:
    category_lookup[cat["id"]] = cat["name"]

category_lookup
# Out:
# {'f1734bdc-1bd8-41d7-a347-608eff237041': 'Electronics',
#  '0c4c8110-d542-431d-87fd-89c15fb61e5b': 'Clothing',
#  '4f2cb014-abf4-42d6-93f8-f801ea7b1173': 'Home and Garden',
#  '1c05029c-c897-4135-a7d0-cb3f9130bb3f': 'Beauty and Personal Care',
#  '7adad1e0-c8e3-4c6d-8d7d-81873cecb006': 'Sports and Outdoors',
#  '167dd0df-3dc4-4f24-84ce-c8fd765905a4': 'Books',
#  '04a586fb-05d6-43e7-8899-82be5e81b1f7': 'Toys and Games',
#  'a9f62412-ab4e-46a4-b908-215d900d4611': 'Groceries'}

# %%
sizes = ["S", "M", "L", "XL"]
colors = ["Black", "White", "Red", "Blue", "Green"]

variants = []
for product in products:
    category_name = category_lookup[product["categoryId"]]
    
    if category_name == "Clothing":
        size = sizes[np.random.randint(0, len(sizes))]
    else:
        size = None
    
    variant = {
        "id": str(uuid.uuid4()),
        "productId": product["id"],
        "sku": str(uuid.uuid4()),
        "size": size,
        "color": colors[np.random.randint(0, len(colors))],
        "stock": np.random.randint(0, 200),
        "price": None
    }
    variants.append(variant)

# %%
varients_df=pd.DataFrame(variants)

# %%
varients_df
# Out:
#                                        id  \
# 0    d06d178d-08da-4f87-9349-ec16221f5486
# 1    7afa640d-5d5c-4e34-b1fe-54e159fbd787
# 2    143ad2c6-7ecc-46e5-9828-ae4c4f92e3f9
# 3    6f6b36d9-dcac-4c1e-b66a-e2684ee4c6c7
# 4    201f3f92-3c71-4f6a-aa46-03be75af415f
# ..                                    ...
# 145  d74e376a-686a-45af-af18-941b8fcd745e
# 146  a651236b-60d9-4ed7-a38b-ac86ddf74c0b
# 147  f24cbd9e-ad3e-4e9d-9de5-7c4fa89e8c88
# 148  69a4a524-1dc3-4a38-b182-fae0426d7754
# 149  d1536aeb-f6dd-45f0-95dc-2de377b9b782
#
#                                 productId  \
# 0    bb483a44-bc2e-4d87-822d-04071d6bc9d2
# 1    730f446e-d92f-42fc-9bda-c2faa1039493
# 2    ba3ede2d-bc2d-4295-819a-acf758e2ffcd
# 3    3a18c9ee-7789-444e-a861-7a357c645238
# 4    d44025be-1f64-46e7-b713-4921303ea488
# ..                                    ...
# 145  aecf5e98-01f3-4fbf-81cf-fbccbf9081f5
# 146  f62ac818-36d6-4f1a-a9dd-846b5046ff40
# 147  bbf6b6f2-9d08-4d58-a6db-3abed090f1cb
# 148  5886affb-c157-4d67-9b8e-71273d373301
# 149  92b97174-851a-4223-8ff2-48252d4c22c3
#
#                                       sku  size  color  stock price
# 0    377f8577-4d60-4c6b-8dc5-9f133bc64c35  None  White    171  None
# 1    10fd3129-3eec-45fb-a2f6-ac670fc4257a  None  Green     49  None
# 2    c7e8bbd4-c491-4daa-8d73-f66acd7d988b  None    Red    159  None
# 3    c70b706e-1887-4402-9872-bd377e1ab449  None  White     75  None
# 4    1f63c186-5a80-4592-b49d-50afc3d399c1    XL  White    105  None
# ..                                    ...   ...    ...    ...   ...
# 145  da4e08ff-f7e2-4b23-b52e-2a29f1c21579  None  White      9  None
# 146  bd914601-d4d5-487e-822f-18abe25f9ef5  None  Green    136  None
# 147  7d58db7b-6afa-4279-a355-674e9b23868b  None  White     79  None
# 148  79ffb056-f01e-4915-ab43-e873d2c964e9  None    Red    192  None
# 149  49b3852f-ca6a-4c71-a9cc-6008956836e1  None  White     60  None
#
# [150 rows x 7 columns]

# %%
varients_df.to_csv("../data/output/product_variants.csv", index=False)

# %% [markdown]
# # 5. Users

# %%
num_user = 2000
users = []

for i in range(num_user):
    user = {
        "id":str(uuid.uuid4()),
        "email":f"user{i}@gmail.com",
        "passwordHash":"placeholder",
        "firstName": f"User{i}",
        "lastName": f"Test{i}",
        "role":"ADMIN" if i == 0 else "CUSTOMER",
        "refreshTokenHash": None,
        "createdAt": "2026-01-01",
        "updatedAt": "2026-01-01"}
    users.append(user)

# %%
users_df = pd.DataFrame(users)

# %%
users_df
# Out:
#                                         id               email passwordHash  \
# 0     fae1faf5-f1c1-4fd6-9cdb-e2b2d764df5f     user0@gmail.com  placeholder
# 1     73cfa26c-afda-4f08-a6e8-c2899e1f9a0c     user1@gmail.com  placeholder
# 2     b6f62ccf-130c-401c-81fd-bdb24cf23917     user2@gmail.com  placeholder
# 3     a0a57413-6002-43f6-8ad9-b62a9d714f7d     user3@gmail.com  placeholder
# 4     8ef512c0-6b9d-4288-92d3-611940ad19e6     user4@gmail.com  placeholder
# ...                                    ...                 ...          ...
# 1995  a2acd94f-fb6f-4ad3-8bd9-70babb5f35ac  user1995@gmail.com  placeholder
# 1996  0905cabb-82d3-444e-a165-3ad343b8e2ff  user1996@gmail.com  placeholder
# 1997  a2c8abc2-5b74-4612-8113-e12b0bc4c559  user1997@gmail.com  placeholder
# 1998  e1a546d0-76ad-4b59-b5d1-1eeaf7138c68  user1998@gmail.com  placeholder
# 1999  dc2325d9-7842-4631-aae6-bb40a845a195  user1999@gmail.com  placeholder
#
#      firstName  lastName      role refreshTokenHash   createdAt   updatedAt
# 0        User0     Test0     ADMIN             None  2026-01-01  2026-01-01
# 1        User1     Test1  CUSTOMER             None  2026-01-01  2026-01-01
# 2        User2     Test2  CUSTOMER             None  2026-01-01  2026-01-01
# 3        User3     Test3  CUSTOMER             None  2026-01-01  2026-01-01
# 4        User4     Test4  CUSTOMER             None  2026-01-01  2026-01-01
# ...        ...       ...       ...              ...         ...         ...
# 1995  User1995  Test1995  CUSTOMER             None  2026-01-01  2026-01-01
# 1996  User1996  Test1996  CUSTOMER             None  2026-01-01  2026-01-01
# 1997  User1997  Test1997  CUSTOMER             None  2026-01-01  2026-01-01
# 1998  User1998  Test1998  CUSTOMER             None  2026-01-01  2026-01-01
# 1999  User1999  Test1999  CUSTOMER             None  2026-01-01  2026-01-01
#
# [2000 rows x 9 columns]

# %%
users_df.to_csv("../data/output/users.csv",index = False)
